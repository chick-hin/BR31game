# %%
def turn(): 
    
    global cur_n 
    number_p = input('1~3사이 정수 입력')
    nbp = int(number_p)

    if (1<=nbp<=3):
        cur_n = cur_n+ nbp  
        print(cur_n)
        
        if cur_n >=31 :
            print('you died')
            sys.exit(1)
        
        print('기계가 입력합니다')
        nbc = 4-nbp
        cur_n = cur_n+ nbc  
        print(cur_n)
        turn()
        
        
    else:
        print ('error 다시 입력하세요')
        turn()

# %%
print('절대 못이기는 베스킨라빈스31 봇 ' )
print('start game')
print('기계가 입력합니다')
cur_n = 2 
print(cur_n)
turn()
# Out:
# 절대 못이기는 베스킨라빈스31 봇
# start game
# 기계가 입력합니다
# 2
# 1~3사이 정수 입력 1
# 3
# 기계가 입력합니다
# 6
# 1~3사이 정수 입력 1
# 7
# 기계가 입력합니다
# 10
# 1~3사이 정수 입력 1
# 11
# 기계가 입력합니다
# 14
# 1~3사이 정수 입력 1
# 15
# 기계가 입력합니다
# 18
# 1~3사이 정수 입력 1
# 19
# 기계가 입력합니다
# 22
# 1~3사이 정수 입력 1
# 23
# 기계가 입력합니다
# 26
# 1~3사이 정수 입력 1
# 27
# 기계가 입력합니다
# 30
# 1~3사이 정수 입력 1
# 31
# you died
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5af4af5ec6c6> in <module>
#       4 cur_n = 2
#       5 print(cur_n)
# ----> 6 turn()
#
# <ipython-input-7-f99357f5ade3> in turn()
#      17         cur_n = cur_n+ nbc
#      18         print(cur_n)
# ---> 19         turn()
#      20
#      21
#
# <ipython-input-7-f99357f5ade3> in turn()
#      17         cur_n = cur_n+ nbc
#      18         print(cur_n)
# ---> 19         turn()
#      20
#      21
#
# <ipython-input-7-f99357f5ade3> in turn()
# ...
